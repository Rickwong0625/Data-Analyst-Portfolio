# %% [markdown]
# # HTML and Inspecting a Web Page

# %% [markdown]
# #this is Tutorial how to inspecting data in a web page

# %% [markdown]
# youtube:
# https://youtu.be/q-kbzWjyPak?si=7a-19vJAuFYhNO7C
#
# https://www.scrapethissite.com/pages/forms/

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
